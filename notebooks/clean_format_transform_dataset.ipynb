# %% [markdown]
# # Installing necessary libraries

# %%
# %pip install skimpy
# Out:
# Requirement already satisfied: skimpy in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (0.0.15)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (2.18.0)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (8.1.7)
# Requirement already satisfied: ipykernel<7.0.0,>=6.7.0 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (6.29.5)
# Requirement already satisfied: numpy<2.0.0,>=1.22.2 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (2.2.3)
# Requirement already satisfied: polars<0.21,>=0.19 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (0.20.31)
# Requirement already satisfied: pyarrow<17,>=13 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (16.1.0)
# Requirement already satisfied: rich<14.0,>=10.9 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (13.9.2)
# Requirement already satisfied: typeguard==4.2.1 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from skimpy) (4.2.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from typeguard==4.2.1->skimpy) (4.12.2)
# Requirement already satisfied: comm>=0.1.1 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.28.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (1.6.0)
# Requirement already satisfied: packaging in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (24.1)
# Requirement already satisfied: psutil in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipykernel<7.0.0,>=6.7.0->skimpy) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.3->skimpy) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from rich<14.0,>=10.9->skimpy) (3.0.0)
# Requirement already satisfied: decorator in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (3.0.48)
# Requirement already satisfied: stack-data in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7.0.0,>=6.7.0->skimpy) (4.3.6)
# Requirement already satisfied: mdurl~=0.1 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=10.9->skimpy) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.3->skimpy) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.7.0)
# Requirement already satisfied: wcwidth in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (2.4.1)
# Requirement already satisfied: pure-eval in /home/uemerson/miniconda3/envs/match_lol_classification/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.7.0->skimpy) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import os
import ast
from skimpy import skim

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load and concatenate matches history datasets

# %%
csv_files = [f for f in os.listdir('../datasets') if f.startswith('match_history_') and f.endswith('.csv')]

dfs = []

for file in csv_files:
    file_path = os.path.join('../datasets', file)
    dfs.append(pd.read_csv(file_path, sep=';'))

df_matches = pd.concat(dfs, ignore_index=True)
df_matches.shape
# Out:
# (16225, 12)

# %%
df_matches.head(5).T
# Out:
#                                                                  0  \
# championship_id         2015_Mid-Season_Invitational/Match_History
# date                                                    2015-05-12
# patch                                                          5.7
# blue_side                                            SK Telecom T1
# red_side                                             EDward Gaming
# winner                                               EDward Gaming
# blue_bans                           ['Hecarim', "Rek'Sai", 'Jinx']
# red_bans                       ['Kalista', 'Gragas', 'Cassiopeia']
# blue_picks        ['Gnar', 'Nunu', 'LeBlanc', 'Urgot', 'Nautilus']
# red_picks        ['Maokai', 'Evelynn', 'Morgana', 'Sivir', 'Ali...
# blue_roster      ['MaRin', 'Bengi', 'Faker', 'Bang', 'Wolf (Lee...
# red_roster         ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
#
#                                                                  1  \
# championship_id         2015_Mid-Season_Invitational/Match_History
# date                                                    2015-05-12
# patch                                                          5.7
# blue_side                                            EDward Gaming
# red_side                                             SK Telecom T1
# winner                                               SK Telecom T1
# blue_bans                       ['Kalista', 'Cassiopeia', 'Urgot']
# red_bans                            ['LeBlanc', "Rek'Sai", 'Jinx']
# blue_picks            ['Maokai', 'Nunu', 'Azir', 'Corki', 'Annie']
# red_picks        ['Gnar', 'Gragas', 'Kassadin', 'Ezreal', 'Alis...
# blue_roster        ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# red_roster       ['MaRin', 'Bengi', 'Faker', 'Bang', 'Wolf (Lee...
#
#                                                                  2  \
# championship_id         2015_Mid-Season_Invitational/Match_History
# date                                                    2015-05-12
# patch                                                          5.7
# blue_side                                            SK Telecom T1
# red_side                                             EDward Gaming
# winner                                               EDward Gaming
# blue_bans                         ['LeBlanc', 'Hecarim', 'Gragas']
# red_bans                        ['Kalista', 'Cassiopeia', 'Urgot']
# blue_picks        ['Rumble', "Rek'Sai", 'Lulu', 'Sivir', 'Thresh']
# red_picks              ['Maokai', 'Nunu', 'Azir', 'Jinx', 'Annie']
# blue_roster      ['MaRin', 'Bengi', 'Easyhoon', 'Bang', 'Wolf (...
# red_roster         ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
#
#                                                                  3  \
# championship_id         2015_Mid-Season_Invitational/Match_History
# date                                                    2015-05-11
# patch                                                          5.7
# blue_side                                            EDward Gaming
# red_side                                          Ahq eSports Club
# winner                                               EDward Gaming
# blue_bans                               ['Zed', 'Maokai', 'Sivir']
# red_bans                         ['Azir', 'Cassiopeia', 'Hecarim']
# blue_picks       ['Irelia', 'Gragas', 'Twisted Fate', 'Urgot', ...
# red_picks          ['Gnar', "Rek'Sai", 'Fizz', 'Kalista', 'Annie']
# blue_roster        ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# red_roster       ['Ziv (Chen Yi)', 'Mountain (Xue Zhao-Hong)', ...
#
#                                                                  4
# championship_id         2015_Mid-Season_Invitational/Match_History
# date                                                    2015-05-11
# patch                                                          5.7
# blue_side                                         Ahq eSports Club
# red_side                                             EDward Gaming
# winner                                               EDward Gaming
# blue_bans                        ['Azir', 'Cassiopeia', 'Hecarim']
# red_bans                           ['Kalista', 'Urgot', "Rek'Sai"]
# blue_picks        ['Gnar', 'Gragas', 'Fizz', 'Lucian', 'Nautilus']
# red_picks        ['Maokai', 'Sejuani', 'Kassadin', 'Sivir', 'Th...
# blue_roster      ['Ziv (Chen Yi)', 'Mountain (Xue Zhao-Hong)', ...
# red_roster         ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']

# %% [markdown]
# # Load and concatenate champions statistics datasets

# %%
csv_files = [f for f in os.listdir('../datasets') if f.startswith('champion_statistics_') and f.endswith('.csv')]

dfs = []

for file in csv_files:
    file_path = os.path.join('../datasets', file)
    dfs.append(pd.read_csv(file_path, sep=';'))

df_champion_statistics = pd.concat(dfs, ignore_index=True)
df_champion_statistics.shape
# Out:
# (18350, 24)

# %%
df_champion_statistics.head(5).T
# Out:
#                                                        0  \
# championship_id           LLA/2019_Season/Opening_Season
# champion                                          Lucian
# games                                                 79
# pb                                                   94%
# b                                                     49
# g                                                     30
# played_by_number_players                               8
# win                                                   19
# lose                                                  11
# winrate                                            63.3%
# kill                                                3.17
# death                                               1.77
# assist                                              4.83
# kda                                                 4.53
# cs                                                   332
# csm                                                 9.42
# gold                                                15.2
# gold_per_m                                           432
# dmg                                                    -
# dmg_per_m                                              -
# kpar                                                 71%
# ks                                                 28.1%
# gs                                                 23.8%
# As                                         ['Bot Laner']
#
#                                                               1  \
# championship_id                  LLA/2019_Season/Opening_Season
# champion                                                  Jayce
# games                                                        72
# pb                                                        85.7%
# b                                                            53
# g                                                            19
# played_by_number_players                                     11
# win                                                          11
# lose                                                          8
# winrate                                                   57.9%
# kill                                                       2.26
# death                                                      2.16
# assist                                                     4.26
# kda                                                        3.02
# cs                                                       267.16
# csm                                                        8.31
# gold                                                       12.7
# gold_per_m                                                  396
# dmg                                                           -
# dmg_per_m                                                     -
# kpar                                                      63.3%
# ks                                                        21.9%
# gs                                                        21.9%
# As                        ['Top Laner', 'Mid Laner', 'Jungler']
#
#                                                                 2  \
# championship_id                    LLA/2019_Season/Opening_Season
# champion                                               Cassiopeia
# games                                                          70
# pb                                                          83.3%
# b                                                              61
# g                                                               9
# played_by_number_players                                        5
# win                                                             6
# lose                                                            3
# winrate                                                     66.7%
# kill                                                         3.11
# death                                                        1.78
# assist                                                       3.56
# kda                                                          3.75
# cs                                                            297
# csm                                                          8.55
# gold                                                         13.8
# gold_per_m                                                    398
# dmg                                                             -
# dmg_per_m                                                       -
# kpar                                                        56.6%
# ks                                                          26.4%
# gs                                                          21.9%
# As                        ['Mid Laner', 'Top Laner', 'Bot Laner']
#
#                                                        3  \
# championship_id           LLA/2019_Season/Opening_Season
# champion                                       Lissandra
# games                                                 64
# pb                                                 76.2%
# b                                                     34
# g                                                     30
# played_by_number_players                              11
# win                                                   15
# lose                                                  15
# winrate                                              50%
# kill                                                1.67
# death                                               2.17
# assist                                              5.53
# kda                                                 3.32
# cs                                                287.23
# csm                                                  8.6
# gold                                                12.7
# gold_per_m                                           379
# dmg                                                    -
# dmg_per_m                                              -
# kpar                                               66.5%
# ks                                                 15.4%
# gs                                                 21.3%
# As                            ['Mid Laner', 'Top Laner']
#
#                                                        4
# championship_id           LLA/2019_Season/Opening_Season
# champion                                           Braum
# games                                                 60
# pb                                                 71.4%
# b                                                     14
# g                                                     46
# played_by_number_players                              10
# win                                                   26
# lose                                                  20
# winrate                                            56.5%
# kill                                                0.54
# death                                               2.04
# assist                                              6.98
# kda                                                 3.68
# cs                                                  75.5
# csm                                                 2.17
# gold                                                 9.9
# gold_per_m                                           284
# dmg                                                    -
# dmg_per_m                                              -
# kpar                                               72.5%
# ks                                                  5.2%
# gs                                                 15.8%
# As                                           ['Support']

# %% [markdown]
# # Load and concatenate players statistics datasets

# %%
csv_files = [f for f in os.listdir('../datasets') if f.startswith('player_statistics_') and f.endswith('.csv')]

dfs = []

for file in csv_files:
    file_path = os.path.join('../datasets', file)
    dfs.append(pd.read_csv(file_path, sep=';'))

df_player_statistics = pd.concat(dfs, ignore_index=True)
df_player_statistics.shape
# Out:
# (12537, 22)

# %%
df_player_statistics.head(5).T
# Out:
#                                                               0  \
# championship_id  2015_Mid-Season_Invitational/Player_Statistics
# team                                           Ahq eSports Club
# player                                                    Albis
# games                                                         8
# w                                                             3
# l                                                             5
# wr                                                        37.5%
# k                                                           1.5
# d                                                           3.5
# a                                                         10.88
# kda                                                        3.54
# cs                                                        37.75
# csm                                                        1.09
# gold                                                        8.3
# gm                                                          238
# dmg                                                           -
# dmgm                                                          -
# kpar                                                      70.7%
# ks                                                         8.6%
# gs                                                        14.1%
# cp                                                            5
# champs                          ['Nautilus', 'Thresh', 'Leona']
#
#                                                               1  \
# championship_id  2015_Mid-Season_Invitational/Player_Statistics
# team                                           Ahq eSports Club
# player                                                       AN
# games                                                         8
# w                                                             3
# l                                                             5
# wr                                                        37.5%
# k                                                          5.88
# d                                                          3.25
# a                                                          6.38
# kda                                                        3.77
# cs                                                       294.88
# csm                                                         8.5
# gold                                                       14.0
# gm                                                          404
# dmg                                                           -
# dmgm                                                          -
# kpar                                                        70%
# ks                                                        33.6%
# gs                                                          24%
# cp                                                            5
# champs                             ['Sivir', 'Kalista', 'Jinx']
#
#                                                               2  \
# championship_id  2015_Mid-Season_Invitational/Player_Statistics
# team                                           Ahq eSports Club
# player                                                 Mountain
# games                                                         8
# w                                                             3
# l                                                             5
# wr                                                        37.5%
# k                                                          2.25
# d                                                          4.25
# a                                                         10.63
# kda                                                        3.03
# cs                                                       120.13
# csm                                                        3.46
# gold                                                       11.4
# gm                                                          328
# dmg                                                           -
# dmgm                                                          -
# kpar                                                      73.6%
# ks                                                        12.9%
# gs                                                        19.5%
# cp                                                            4
# champs                      ["Rek'Sai", 'Sejuani', 'Jarvan IV']
#
#                                                               3  \
# championship_id  2015_Mid-Season_Invitational/Player_Statistics
# team                                           Ahq eSports Club
# player                                                 westdoor
# games                                                         8
# w                                                             3
# l                                                             5
# wr                                                        37.5%
# k                                                          4.75
# d                                                          3.25
# a                                                          7.38
# kda                                                        3.73
# cs                                                       276.38
# csm                                                        7.97
# gold                                                       13.6
# gm                                                          393
# dmg                                                           -
# dmgm                                                          -
# kpar                                                      69.3%
# ks                                                        27.1%
# gs                                                        23.4%
# cp                                                            4
# champs                      ['Fizz', 'Twisted Fate', 'Karthus']
#
#                                                               4
# championship_id  2015_Mid-Season_Invitational/Player_Statistics
# team                                           Ahq eSports Club
# player                                                      Ziv
# games                                                         8
# w                                                             3
# l                                                             5
# wr                                                        37.5%
# k                                                          3.13
# d                                                          3.75
# a                                                           9.0
# kda                                                        3.23
# cs                                                       208.75
# csm                                                        6.02
# gold                                                       11.4
# gm                                                          328
# dmg                                                           -
# dmgm                                                          -
# kpar                                                      69.3%
# ks                                                        17.9%
# gs                                                        19.5%
# cp                                                            2
# champs                                       ['Gnar', 'Maokai']

# %% [markdown]
# # Create target feature

# %%
df_transformed = df_matches.copy()

df_transformed['target'] = None
df_transformed.loc[df_transformed['blue_side'] == df_transformed['winner'], 'target'] = 1
df_transformed.loc[df_transformed['red_side'] == df_transformed['winner'], 'target'] = 0

# %% [markdown]
# # Blue and red picks winrate and kda

# %%
for column in ['blue_pick_top', 'blue_pick_jungle', 'blue_pick_mid', 'blue_pick_adc', 'blue_pick_support']:
    df_transformed[f"{column}_win"] = None
    df_transformed[f"{column}_kda"] = None

df_transformed['blue_picks'] = df_transformed['blue_picks'].apply(ast.literal_eval)
df_transformed[['blue_pick_top', 'blue_pick_jungle', 'blue_pick_mid', 'blue_pick_adc', 'blue_pick_support']] = pd.DataFrame(df_transformed['blue_picks'].tolist(), index=df_transformed.index)

for column in ['red_pick_top', 'red_pick_jungle', 'red_pick_mid', 'red_pick_adc', 'red_pick_support']:
    df_transformed[f"{column}_win"] = None
    df_transformed[f"{column}_kda"] = None

df_transformed['red_picks'] = df_transformed['red_picks'].apply(ast.literal_eval)
df_transformed[['red_pick_top', 'red_pick_jungle', 'red_pick_mid', 'red_pick_adc', 'red_pick_support']] = pd.DataFrame(df_transformed['red_picks'].tolist(), index=df_transformed.index)

df_transformed.head(5).T
# Out:
#                                                                        0  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  SK Telecom T1
# red_side                                                   EDward Gaming
# winner                                                     EDward Gaming
# blue_bans                                 ['Hecarim', "Rek'Sai", 'Jinx']
# red_bans                             ['Kalista', 'Gragas', 'Cassiopeia']
# blue_picks                        [Gnar, Nunu, LeBlanc, Urgot, Nautilus]
# red_picks                     [Maokai, Evelynn, Morgana, Sivir, Alistar]
# blue_roster            ['MaRin', 'Bengi', 'Faker', 'Bang', 'Wolf (Lee...
# red_roster               ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# target                                                                 0
# blue_pick_top_win                                                   None
# blue_pick_top_kda                                                   None
# blue_pick_jungle_win                                                None
# blue_pick_jungle_kda                                                None
# blue_pick_mid_win                                                   None
# blue_pick_mid_kda                                                   None
# blue_pick_adc_win                                                   None
# blue_pick_adc_kda                                                   None
# blue_pick_support_win                                               None
# blue_pick_support_kda                                               None
# blue_pick_top                                                       Gnar
# blue_pick_jungle                                                    Nunu
# blue_pick_mid                                                    LeBlanc
# blue_pick_adc                                                      Urgot
# blue_pick_support                                               Nautilus
# red_pick_top_win                                                    None
# red_pick_top_kda                                                    None
# red_pick_jungle_win                                                 None
# red_pick_jungle_kda                                                 None
# red_pick_mid_win                                                    None
# red_pick_mid_kda                                                    None
# red_pick_adc_win                                                    None
# red_pick_adc_kda                                                    None
# red_pick_support_win                                                None
# red_pick_support_kda                                                None
# red_pick_top                                                      Maokai
# red_pick_jungle                                                  Evelynn
# red_pick_mid                                                     Morgana
# red_pick_adc                                                       Sivir
# red_pick_support                                                 Alistar
#
#                                                                        1  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  EDward Gaming
# red_side                                                   SK Telecom T1
# winner                                                     SK Telecom T1
# blue_bans                             ['Kalista', 'Cassiopeia', 'Urgot']
# red_bans                                  ['LeBlanc', "Rek'Sai", 'Jinx']
# blue_picks                            [Maokai, Nunu, Azir, Corki, Annie]
# red_picks                      [Gnar, Gragas, Kassadin, Ezreal, Alistar]
# blue_roster              ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# red_roster             ['MaRin', 'Bengi', 'Faker', 'Bang', 'Wolf (Lee...
# target                                                                 0
# blue_pick_top_win                                                   None
# blue_pick_top_kda                                                   None
# blue_pick_jungle_win                                                None
# blue_pick_jungle_kda                                                None
# blue_pick_mid_win                                                   None
# blue_pick_mid_kda                                                   None
# blue_pick_adc_win                                                   None
# blue_pick_adc_kda                                                   None
# blue_pick_support_win                                               None
# blue_pick_support_kda                                               None
# blue_pick_top                                                     Maokai
# blue_pick_jungle                                                    Nunu
# blue_pick_mid                                                       Azir
# blue_pick_adc                                                      Corki
# blue_pick_support                                                  Annie
# red_pick_top_win                                                    None
# red_pick_top_kda                                                    None
# red_pick_jungle_win                                                 None
# red_pick_jungle_kda                                                 None
# red_pick_mid_win                                                    None
# red_pick_mid_kda                                                    None
# red_pick_adc_win                                                    None
# red_pick_adc_kda                                                    None
# red_pick_support_win                                                None
# red_pick_support_kda                                                None
# red_pick_top                                                        Gnar
# red_pick_jungle                                                   Gragas
# red_pick_mid                                                    Kassadin
# red_pick_adc                                                      Ezreal
# red_pick_support                                                 Alistar
#
#                                                                        2  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  SK Telecom T1
# red_side                                                   EDward Gaming
# winner                                                     EDward Gaming
# blue_bans                               ['LeBlanc', 'Hecarim', 'Gragas']
# red_bans                              ['Kalista', 'Cassiopeia', 'Urgot']
# blue_picks                        [Rumble, Rek'Sai, Lulu, Sivir, Thresh]
# red_picks                              [Maokai, Nunu, Azir, Jinx, Annie]
# blue_roster            ['MaRin', 'Bengi', 'Easyhoon', 'Bang', 'Wolf (...
# red_roster               ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# target                                                                 0
# blue_pick_top_win                                                   None
# blue_pick_top_kda                                                   None
# blue_pick_jungle_win                                                None
# blue_pick_jungle_kda                                                None
# blue_pick_mid_win                                                   None
# blue_pick_mid_kda                                                   None
# blue_pick_adc_win                                                   None
# blue_pick_adc_kda                                                   None
# blue_pick_support_win                                               None
# blue_pick_support_kda                                               None
# blue_pick_top                                                     Rumble
# blue_pick_jungle                                                 Rek'Sai
# blue_pick_mid                                                       Lulu
# blue_pick_adc                                                      Sivir
# blue_pick_support                                                 Thresh
# red_pick_top_win                                                    None
# red_pick_top_kda                                                    None
# red_pick_jungle_win                                                 None
# red_pick_jungle_kda                                                 None
# red_pick_mid_win                                                    None
# red_pick_mid_kda                                                    None
# red_pick_adc_win                                                    None
# red_pick_adc_kda                                                    None
# red_pick_support_win                                                None
# red_pick_support_kda                                                None
# red_pick_top                                                      Maokai
# red_pick_jungle                                                     Nunu
# red_pick_mid                                                        Azir
# red_pick_adc                                                        Jinx
# red_pick_support                                                   Annie
#
#                                                                        3  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-11
# patch                                                                5.7
# blue_side                                                  EDward Gaming
# red_side                                                Ahq eSports Club
# winner                                                     EDward Gaming
# blue_bans                                     ['Zed', 'Maokai', 'Sivir']
# red_bans                               ['Azir', 'Cassiopeia', 'Hecarim']
# blue_picks                 [Irelia, Gragas, Twisted Fate, Urgot, Thresh]
# red_picks                          [Gnar, Rek'Sai, Fizz, Kalista, Annie]
# blue_roster              ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# red_roster             ['Ziv (Chen Yi)', 'Mountain (Xue Zhao-Hong)', ...
# target                                                                 1
# blue_pick_top_win                                                   None
# blue_pick_top_kda                                                   None
# blue_pick_jungle_win                                                None
# blue_pick_jungle_kda                                                None
# blue_pick_mid_win                                                   None
# blue_pick_mid_kda                                                   None
# blue_pick_adc_win                                                   None
# blue_pick_adc_kda                                                   None
# blue_pick_support_win                                               None
# blue_pick_support_kda                                               None
# blue_pick_top                                                     Irelia
# blue_pick_jungle                                                  Gragas
# blue_pick_mid                                               Twisted Fate
# blue_pick_adc                                                      Urgot
# blue_pick_support                                                 Thresh
# red_pick_top_win                                                    None
# red_pick_top_kda                                                    None
# red_pick_jungle_win                                                 None
# red_pick_jungle_kda                                                 None
# red_pick_mid_win                                                    None
# red_pick_mid_kda                                                    None
# red_pick_adc_win                                                    None
# red_pick_adc_kda                                                    None
# red_pick_support_win                                                None
# red_pick_support_kda                                                None
# red_pick_top                                                        Gnar
# red_pick_jungle                                                  Rek'Sai
# red_pick_mid                                                        Fizz
# red_pick_adc                                                     Kalista
# red_pick_support                                                   Annie
#
#                                                                        4
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-11
# patch                                                                5.7
# blue_side                                               Ahq eSports Club
# red_side                                                   EDward Gaming
# winner                                                     EDward Gaming
# blue_bans                              ['Azir', 'Cassiopeia', 'Hecarim']
# red_bans                                 ['Kalista', 'Urgot', "Rek'Sai"]
# blue_picks                        [Gnar, Gragas, Fizz, Lucian, Nautilus]
# red_picks                     [Maokai, Sejuani, Kassadin, Sivir, Thresh]
# blue_roster            ['Ziv (Chen Yi)', 'Mountain (Xue Zhao-Hong)', ...
# red_roster               ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# target                                                                 0
# blue_pick_top_win                                                   None
# blue_pick_top_kda                                                   None
# blue_pick_jungle_win                                                None
# blue_pick_jungle_kda                                                None
# blue_pick_mid_win                                                   None
# blue_pick_mid_kda                                                   None
# blue_pick_adc_win                                                   None
# blue_pick_adc_kda                                                   None
# blue_pick_support_win                                               None
# blue_pick_support_kda                                               None
# blue_pick_top                                                       Gnar
# blue_pick_jungle                                                  Gragas
# blue_pick_mid                                                       Fizz
# blue_pick_adc                                                     Lucian
# blue_pick_support                                               Nautilus
# red_pick_top_win                                                    None
# red_pick_top_kda                                                    None
# red_pick_jungle_win                                                 None
# red_pick_jungle_kda                                                 None
# red_pick_mid_win                                                    None
# red_pick_mid_kda                                                    None
# red_pick_adc_win                                                    None
# red_pick_adc_kda                                                    None
# red_pick_support_win                                                None
# red_pick_support_kda                                                None
# red_pick_top                                                      Maokai
# red_pick_jungle                                                  Sejuani
# red_pick_mid                                                    Kassadin
# red_pick_adc                                                       Sivir
# red_pick_support                                                  Thresh

# %%
# generate keys to merge
df_transformed['mg_championship_id'] = df_transformed['championship_id']
df_transformed['mg_championship_id'] = df_transformed['championship_id'].str.replace(
    '/Match_History', '', regex=False)

df_champion_statistics['mg_championship_id'] = df_champion_statistics['championship_id']
df_champion_statistics['mg_championship_id'] = df_champion_statistics['championship_id'].str.replace(
    '/Champion_Statistics', '', regex=False)

# merge winrate and kda of blue picks
for column in ['blue_pick_top', 'blue_pick_jungle', 'blue_pick_mid', 'blue_pick_adc', 'blue_pick_support']:
    df_merge = df_transformed.merge(
        df_champion_statistics[['mg_championship_id', 'winrate', 'kda', 'champion']],
        left_on=['mg_championship_id', column],
        right_on=['mg_championship_id', 'champion'],
        how='left'
    )
    df_merge['winrate'] = df_merge['winrate'].str.replace('%', '', regex=False).astype(float)
    df_merge['kda'] = df_merge['kda'].astype(float)
    df_transformed[f"{column}_win"] = df_merge['winrate']
    df_transformed[f"{column}_kda"] = df_merge['kda']

# merge winrate and kda of red picks
for column in ['red_pick_top', 'red_pick_jungle', 'red_pick_mid', 'red_pick_adc', 'red_pick_support']:
    df_merge = df_transformed.merge(
        df_champion_statistics[['mg_championship_id', 'winrate', 'kda', 'champion']],
        left_on=['mg_championship_id', column],
        right_on=['mg_championship_id', 'champion'],
        how='left'
    )
    df_merge['winrate'] = df_merge['winrate'].str.replace('%', '', regex=False).astype(float)
    df_merge['kda'] = df_merge['kda'].astype(float)
    df_transformed[f"{column}_win"] = df_merge['winrate']
    df_transformed[f"{column}_kda"] = df_merge['kda']

# %%
df_transformed.head(5).T
# Out:
#                                                                        0  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  SK Telecom T1
# red_side                                                   EDward Gaming
# winner                                                     EDward Gaming
# blue_bans                                 ['Hecarim', "Rek'Sai", 'Jinx']
# red_bans                             ['Kalista', 'Gragas', 'Cassiopeia']
# blue_picks                        [Gnar, Nunu, LeBlanc, Urgot, Nautilus]
# red_picks                     [Maokai, Evelynn, Morgana, Sivir, Alistar]
# blue_roster            ['MaRin', 'Bengi', 'Faker', 'Bang', 'Wolf (Lee...
# red_roster               ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# target                                                                 0
# blue_pick_top_win                                                   38.9
# blue_pick_top_kda                                                   2.64
# blue_pick_jungle_win                                                60.0
# blue_pick_jungle_kda                                                4.36
# blue_pick_mid_win                                                   60.0
# blue_pick_mid_kda                                                   6.44
# blue_pick_adc_win                                                   66.7
# blue_pick_adc_kda                                                   2.84
# blue_pick_support_win                                               33.3
# blue_pick_support_kda                                               2.85
# blue_pick_top                                                       Gnar
# blue_pick_jungle                                                    Nunu
# blue_pick_mid                                                    LeBlanc
# blue_pick_adc                                                      Urgot
# blue_pick_support                                               Nautilus
# red_pick_top_win                                                    76.9
# red_pick_top_kda                                                    5.57
# red_pick_jungle_win                                                100.0
# red_pick_jungle_kda                                                 22.0
# red_pick_mid_win                                                    33.3
# red_pick_mid_kda                                                    2.25
# red_pick_adc_win                                                    23.5
# red_pick_adc_kda                                                    3.31
# red_pick_support_win                                                77.8
# red_pick_support_kda                                                4.62
# red_pick_top                                                      Maokai
# red_pick_jungle                                                  Evelynn
# red_pick_mid                                                     Morgana
# red_pick_adc                                                       Sivir
# red_pick_support                                                 Alistar
# mg_championship_id                          2015_Mid-Season_Invitational
#
#                                                                        1  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  EDward Gaming
# red_side                                                   SK Telecom T1
# winner                                                     SK Telecom T1
# blue_bans                             ['Kalista', 'Cassiopeia', 'Urgot']
# red_bans                                  ['LeBlanc', "Rek'Sai", 'Jinx']
# blue_picks                            [Maokai, Nunu, Azir, Corki, Annie]
# red_picks                      [Gnar, Gragas, Kassadin, Ezreal, Alistar]
# blue_roster              ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# red_roster             ['MaRin', 'Bengi', 'Faker', 'Bang', 'Wolf (Lee...
# target                                                                 0
# blue_pick_top_win                                                   76.9
# blue_pick_top_kda                                                   5.57
# blue_pick_jungle_win                                                60.0
# blue_pick_jungle_kda                                                4.36
# blue_pick_mid_win                                                   71.4
# blue_pick_mid_kda                                                    6.0
# blue_pick_adc_win                                                   33.3
# blue_pick_adc_kda                                                   2.42
# blue_pick_support_win                                               62.5
# blue_pick_support_kda                                               4.55
# blue_pick_top                                                     Maokai
# blue_pick_jungle                                                    Nunu
# blue_pick_mid                                                       Azir
# blue_pick_adc                                                      Corki
# blue_pick_support                                                  Annie
# red_pick_top_win                                                    38.9
# red_pick_top_kda                                                    2.64
# red_pick_jungle_win                                                 53.3
# red_pick_jungle_kda                                                 3.63
# red_pick_mid_win                                                   100.0
# red_pick_mid_kda                                                   14.33
# red_pick_adc_win                                                   100.0
# red_pick_adc_kda                                                   16.33
# red_pick_support_win                                                77.8
# red_pick_support_kda                                                4.62
# red_pick_top                                                        Gnar
# red_pick_jungle                                                   Gragas
# red_pick_mid                                                    Kassadin
# red_pick_adc                                                      Ezreal
# red_pick_support                                                 Alistar
# mg_championship_id                          2015_Mid-Season_Invitational
#
#                                                                        2  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  SK Telecom T1
# red_side                                                   EDward Gaming
# winner                                                     EDward Gaming
# blue_bans                               ['LeBlanc', 'Hecarim', 'Gragas']
# red_bans                              ['Kalista', 'Cassiopeia', 'Urgot']
# blue_picks                        [Rumble, Rek'Sai, Lulu, Sivir, Thresh]
# red_picks                              [Maokai, Nunu, Azir, Jinx, Annie]
# blue_roster            ['MaRin', 'Bengi', 'Easyhoon', 'Bang', 'Wolf (...
# red_roster               ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# target                                                                 0
# blue_pick_top_win                                                   45.5
# blue_pick_top_kda                                                   1.75
# blue_pick_jungle_win                                                60.0
# blue_pick_jungle_kda                                                4.09
# blue_pick_mid_win                                                   16.7
# blue_pick_mid_kda                                                   0.91
# blue_pick_adc_win                                                   23.5
# blue_pick_adc_kda                                                   3.31
# blue_pick_support_win                                               60.0
# blue_pick_support_kda                                               3.52
# blue_pick_top                                                     Rumble
# blue_pick_jungle                                                 Rek'Sai
# blue_pick_mid                                                       Lulu
# blue_pick_adc                                                      Sivir
# blue_pick_support                                                 Thresh
# red_pick_top_win                                                    76.9
# red_pick_top_kda                                                    5.57
# red_pick_jungle_win                                                 60.0
# red_pick_jungle_kda                                                 4.36
# red_pick_mid_win                                                    71.4
# red_pick_mid_kda                                                     6.0
# red_pick_adc_win                                                   100.0
# red_pick_adc_kda                                                     8.0
# red_pick_support_win                                                62.5
# red_pick_support_kda                                                4.55
# red_pick_top                                                      Maokai
# red_pick_jungle                                                     Nunu
# red_pick_mid                                                        Azir
# red_pick_adc                                                        Jinx
# red_pick_support                                                   Annie
# mg_championship_id                          2015_Mid-Season_Invitational
#
#                                                                        3  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-11
# patch                                                                5.7
# blue_side                                                  EDward Gaming
# red_side                                                Ahq eSports Club
# winner                                                     EDward Gaming
# blue_bans                                     ['Zed', 'Maokai', 'Sivir']
# red_bans                               ['Azir', 'Cassiopeia', 'Hecarim']
# blue_picks                 [Irelia, Gragas, Twisted Fate, Urgot, Thresh]
# red_picks                          [Gnar, Rek'Sai, Fizz, Kalista, Annie]
# blue_roster              ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# red_roster             ['Ziv (Chen Yi)', 'Mountain (Xue Zhao-Hong)', ...
# target                                                                 1
# blue_pick_top_win                                                  100.0
# blue_pick_top_kda                                                   19.0
# blue_pick_jungle_win                                                53.3
# blue_pick_jungle_kda                                                3.63
# blue_pick_mid_win                                                   75.0
# blue_pick_mid_kda                                                    5.1
# blue_pick_adc_win                                                   66.7
# blue_pick_adc_kda                                                   2.84
# blue_pick_support_win                                               60.0
# blue_pick_support_kda                                               3.52
# blue_pick_top                                                     Irelia
# blue_pick_jungle                                                  Gragas
# blue_pick_mid                                               Twisted Fate
# blue_pick_adc                                                      Urgot
# blue_pick_support                                                 Thresh
# red_pick_top_win                                                    38.9
# red_pick_top_kda                                                    2.64
# red_pick_jungle_win                                                 60.0
# red_pick_jungle_kda                                                 4.09
# red_pick_mid_win                                                    50.0
# red_pick_mid_kda                                                     4.5
# red_pick_adc_win                                                    60.0
# red_pick_adc_kda                                                    3.45
# red_pick_support_win                                                62.5
# red_pick_support_kda                                                4.55
# red_pick_top                                                        Gnar
# red_pick_jungle                                                  Rek'Sai
# red_pick_mid                                                        Fizz
# red_pick_adc                                                     Kalista
# red_pick_support                                                   Annie
# mg_championship_id                          2015_Mid-Season_Invitational
#
#                                                                        4
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-11
# patch                                                                5.7
# blue_side                                               Ahq eSports Club
# red_side                                                   EDward Gaming
# winner                                                     EDward Gaming
# blue_bans                              ['Azir', 'Cassiopeia', 'Hecarim']
# red_bans                                 ['Kalista', 'Urgot', "Rek'Sai"]
# blue_picks                        [Gnar, Gragas, Fizz, Lucian, Nautilus]
# red_picks                     [Maokai, Sejuani, Kassadin, Sivir, Thresh]
# blue_roster            ['Ziv (Chen Yi)', 'Mountain (Xue Zhao-Hong)', ...
# red_roster               ['Koro1', 'Clearlove', 'PawN', 'Deft', 'Meiko']
# target                                                                 0
# blue_pick_top_win                                                   38.9
# blue_pick_top_kda                                                   2.64
# blue_pick_jungle_win                                                53.3
# blue_pick_jungle_kda                                                3.63
# blue_pick_mid_win                                                   50.0
# blue_pick_mid_kda                                                    4.5
# blue_pick_adc_win                                                   37.5
# blue_pick_adc_kda                                                   2.03
# blue_pick_support_win                                               33.3
# blue_pick_support_kda                                               2.85
# blue_pick_top                                                       Gnar
# blue_pick_jungle                                                  Gragas
# blue_pick_mid                                                       Fizz
# blue_pick_adc                                                     Lucian
# blue_pick_support                                               Nautilus
# red_pick_top_win                                                    76.9
# red_pick_top_kda                                                    5.57
# red_pick_jungle_win                                                 23.1
# red_pick_jungle_kda                                                 2.43
# red_pick_mid_win                                                   100.0
# red_pick_mid_kda                                                   14.33
# red_pick_adc_win                                                    23.5
# red_pick_adc_kda                                                    3.31
# red_pick_support_win                                                60.0
# red_pick_support_kda                                                3.52
# red_pick_top                                                      Maokai
# red_pick_jungle                                                  Sejuani
# red_pick_mid                                                    Kassadin
# red_pick_adc                                                       Sivir
# red_pick_support                                                  Thresh
# mg_championship_id                          2015_Mid-Season_Invitational

# %% [markdown]
# ## Blue and red rosters winrate and kda

# %%
for column in ['blue_roster_top', 'blue_roster_jungle', 'blue_roster_mid', 'blue_roster_adc', 'blue_roster_support']:
    df_transformed[f"{column}_win"] = None
    df_transformed[f"{column}_kda"] = None

df_transformed['blue_roster'] = df_transformed['blue_roster'].apply(ast.literal_eval)
df_transformed[['blue_roster_top', 'blue_roster_jungle', 'blue_roster_mid', 'blue_roster_adc', 'blue_roster_support']] = pd.DataFrame(df_transformed['blue_roster'].tolist(), index=df_transformed.index)

for column in ['red_roster_top', 'red_roster_jungle', 'red_roster_mid', 'red_roster_adc', 'red_roster_support']:
    df_transformed[f"{column}_win"] = None
    df_transformed[f"{column}_kda"] = None

df_transformed['red_roster'] = df_transformed['red_roster'].apply(ast.literal_eval)
df_transformed[['red_roster_top', 'red_roster_jungle', 'red_roster_mid', 'red_roster_adc', 'red_roster_support']] = pd.DataFrame(df_transformed['red_roster'].tolist(), index=df_transformed.index)

# remove names between parenthesis
for column in ['blue_roster_top', 'blue_roster_jungle', 
               'blue_roster_mid', 'blue_roster_adc', 'blue_roster_support',
               'red_roster_top', 'red_roster_jungle', 
               'red_roster_mid', 'red_roster_adc', 'red_roster_support']:
    df_transformed[column] = df_transformed[column].str.replace(r'\s*\(.*?\)\s*', '', regex=True)
    df_transformed[column] = df_transformed[column].str.lower()

df_transformed.head(5).T
# Out:
#                                                                        0  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  SK Telecom T1
# red_side                                                   EDward Gaming
# winner                                                     EDward Gaming
# blue_bans                                 ['Hecarim', "Rek'Sai", 'Jinx']
# red_bans                             ['Kalista', 'Gragas', 'Cassiopeia']
# blue_picks                        [Gnar, Nunu, LeBlanc, Urgot, Nautilus]
# red_picks                     [Maokai, Evelynn, Morgana, Sivir, Alistar]
# blue_roster              [MaRin, Bengi, Faker, Bang, Wolf (Lee Jae-wan)]
# red_roster                         [Koro1, Clearlove, PawN, Deft, Meiko]
# target                                                                 0
# blue_pick_top_win                                                   38.9
# blue_pick_top_kda                                                   2.64
# blue_pick_jungle_win                                                60.0
# blue_pick_jungle_kda                                                4.36
# blue_pick_mid_win                                                   60.0
# blue_pick_mid_kda                                                   6.44
# blue_pick_adc_win                                                   66.7
# blue_pick_adc_kda                                                   2.84
# blue_pick_support_win                                               33.3
# blue_pick_support_kda                                               2.85
# blue_pick_top                                                       Gnar
# blue_pick_jungle                                                    Nunu
# blue_pick_mid                                                    LeBlanc
# blue_pick_adc                                                      Urgot
# blue_pick_support                                               Nautilus
# red_pick_top_win                                                    76.9
# red_pick_top_kda                                                    5.57
# red_pick_jungle_win                                                100.0
# red_pick_jungle_kda                                                 22.0
# red_pick_mid_win                                                    33.3
# red_pick_mid_kda                                                    2.25
# red_pick_adc_win                                                    23.5
# red_pick_adc_kda                                                    3.31
# red_pick_support_win                                                77.8
# red_pick_support_kda                                                4.62
# red_pick_top                                                      Maokai
# red_pick_jungle                                                  Evelynn
# red_pick_mid                                                     Morgana
# red_pick_adc                                                       Sivir
# red_pick_support                                                 Alistar
# mg_championship_id                          2015_Mid-Season_Invitational
# blue_roster_top_win                                                 None
# blue_roster_top_kda                                                 None
# blue_roster_jungle_win                                              None
# blue_roster_jungle_kda                                              None
# blue_roster_mid_win                                                 None
# blue_roster_mid_kda                                                 None
# blue_roster_adc_win                                                 None
# blue_roster_adc_kda                                                 None
# blue_roster_support_win                                             None
# blue_roster_support_kda                                             None
# blue_roster_top                                                    marin
# blue_roster_jungle                                                 bengi
# blue_roster_mid                                                    faker
# blue_roster_adc                                                     bang
# blue_roster_support                                                 wolf
# red_roster_top_win                                                  None
# red_roster_top_kda                                                  None
# red_roster_jungle_win                                               None
# red_roster_jungle_kda                                               None
# red_roster_mid_win                                                  None
# red_roster_mid_kda                                                  None
# red_roster_adc_win                                                  None
# red_roster_adc_kda                                                  None
# red_roster_support_win                                              None
# red_roster_support_kda                                              None
# red_roster_top                                                     koro1
# red_roster_jungle                                              clearlove
# red_roster_mid                                                      pawn
# red_roster_adc                                                      deft
# red_roster_support                                                 meiko
#
#                                                                        1  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  EDward Gaming
# red_side                                                   SK Telecom T1
# winner                                                     SK Telecom T1
# blue_bans                             ['Kalista', 'Cassiopeia', 'Urgot']
# red_bans                                  ['LeBlanc', "Rek'Sai", 'Jinx']
# blue_picks                            [Maokai, Nunu, Azir, Corki, Annie]
# red_picks                      [Gnar, Gragas, Kassadin, Ezreal, Alistar]
# blue_roster                        [Koro1, Clearlove, PawN, Deft, Meiko]
# red_roster               [MaRin, Bengi, Faker, Bang, Wolf (Lee Jae-wan)]
# target                                                                 0
# blue_pick_top_win                                                   76.9
# blue_pick_top_kda                                                   5.57
# blue_pick_jungle_win                                                60.0
# blue_pick_jungle_kda                                                4.36
# blue_pick_mid_win                                                   71.4
# blue_pick_mid_kda                                                    6.0
# blue_pick_adc_win                                                   33.3
# blue_pick_adc_kda                                                   2.42
# blue_pick_support_win                                               62.5
# blue_pick_support_kda                                               4.55
# blue_pick_top                                                     Maokai
# blue_pick_jungle                                                    Nunu
# blue_pick_mid                                                       Azir
# blue_pick_adc                                                      Corki
# blue_pick_support                                                  Annie
# red_pick_top_win                                                    38.9
# red_pick_top_kda                                                    2.64
# red_pick_jungle_win                                                 53.3
# red_pick_jungle_kda                                                 3.63
# red_pick_mid_win                                                   100.0
# red_pick_mid_kda                                                   14.33
# red_pick_adc_win                                                   100.0
# red_pick_adc_kda                                                   16.33
# red_pick_support_win                                                77.8
# red_pick_support_kda                                                4.62
# red_pick_top                                                        Gnar
# red_pick_jungle                                                   Gragas
# red_pick_mid                                                    Kassadin
# red_pick_adc                                                      Ezreal
# red_pick_support                                                 Alistar
# mg_championship_id                          2015_Mid-Season_Invitational
# blue_roster_top_win                                                 None
# blue_roster_top_kda                                                 None
# blue_roster_jungle_win                                              None
# blue_roster_jungle_kda                                              None
# blue_roster_mid_win                                                 None
# blue_roster_mid_kda                                                 None
# blue_roster_adc_win                                                 None
# blue_roster_adc_kda                                                 None
# blue_roster_support_win                                             None
# blue_roster_support_kda                                             None
# blue_roster_top                                                    koro1
# blue_roster_jungle                                             clearlove
# blue_roster_mid                                                     pawn
# blue_roster_adc                                                     deft
# blue_roster_support                                                meiko
# red_roster_top_win                                                  None
# red_roster_top_kda                                                  None
# red_roster_jungle_win                                               None
# red_roster_jungle_kda                                               None
# red_roster_mid_win                                                  None
# red_roster_mid_kda                                                  None
# red_roster_adc_win                                                  None
# red_roster_adc_kda                                                  None
# red_roster_support_win                                              None
# red_roster_support_kda                                              None
# red_roster_top                                                     marin
# red_roster_jungle                                                  bengi
# red_roster_mid                                                     faker
# red_roster_adc                                                      bang
# red_roster_support                                                  wolf
#
#                                                                          2  \
# championship_id                 2015_Mid-Season_Invitational/Match_History
# date                                                            2015-05-12
# patch                                                                  5.7
# blue_side                                                    SK Telecom T1
# red_side                                                     EDward Gaming
# winner                                                       EDward Gaming
# blue_bans                                 ['LeBlanc', 'Hecarim', 'Gragas']
# red_bans                                ['Kalista', 'Cassiopeia', 'Urgot']
# blue_picks                          [Rumble, Rek'Sai, Lulu, Sivir, Thresh]
# red_picks                                [Maokai, Nunu, Azir, Jinx, Annie]
# blue_roster              [MaRin, Bengi, Easyhoon, Bang, Wolf (Lee Jae-w...
# red_roster                           [Koro1, Clearlove, PawN, Deft, Meiko]
# target                                                                   0
# blue_pick_top_win                                                     45.5
# blue_pick_top_kda                                                     1.75
# blue_pick_jungle_win                                                  60.0
# blue_pick_jungle_kda                                                  4.09
# blue_pick_mid_win                                                     16.7
# blue_pick_mid_kda                                                     0.91
# blue_pick_adc_win                                                     23.5
# blue_pick_adc_kda                                                     3.31
# blue_pick_support_win                                                 60.0
# blue_pick_support_kda                                                 3.52
# blue_pick_top                                                       Rumble
# blue_pick_jungle                                                   Rek'Sai
# blue_pick_mid                                                         Lulu
# blue_pick_adc                                                        Sivir
# blue_pick_support                                                   Thresh
# red_pick_top_win                                                      76.9
# red_pick_top_kda                                                      5.57
# red_pick_jungle_win                                                   60.0
# red_pick_jungle_kda                                                   4.36
# red_pick_mid_win                                                      71.4
# red_pick_mid_kda                                                       6.0
# red_pick_adc_win                                                     100.0
# red_pick_adc_kda                                                       8.0
# red_pick_support_win                                                  62.5
# red_pick_support_kda                                                  4.55
# red_pick_top                                                        Maokai
# red_pick_jungle                                                       Nunu
# red_pick_mid                                                          Azir
# red_pick_adc                                                          Jinx
# red_pick_support                                                     Annie
# mg_championship_id                            2015_Mid-Season_Invitational
# blue_roster_top_win                                                   None
# blue_roster_top_kda                                                   None
# blue_roster_jungle_win                                                None
# blue_roster_jungle_kda                                                None
# blue_roster_mid_win                                                   None
# blue_roster_mid_kda                                                   None
# blue_roster_adc_win                                                   None
# blue_roster_adc_kda                                                   None
# blue_roster_support_win                                               None
# blue_roster_support_kda                                               None
# blue_roster_top                                                      marin
# blue_roster_jungle                                                   bengi
# blue_roster_mid                                                   easyhoon
# blue_roster_adc                                                       bang
# blue_roster_support                                                   wolf
# red_roster_top_win                                                    None
# red_roster_top_kda                                                    None
# red_roster_jungle_win                                                 None
# red_roster_jungle_kda                                                 None
# red_roster_mid_win                                                    None
# red_roster_mid_kda                                                    None
# red_roster_adc_win                                                    None
# red_roster_adc_kda                                                    None
# red_roster_support_win                                                None
# red_roster_support_kda                                                None
# red_roster_top                                                       koro1
# red_roster_jungle                                                clearlove
# red_roster_mid                                                        pawn
# red_roster_adc                                                        deft
# red_roster_support                                                   meiko
#
#                                                                          3  \
# championship_id                 2015_Mid-Season_Invitational/Match_History
# date                                                            2015-05-11
# patch                                                                  5.7
# blue_side                                                    EDward Gaming
# red_side                                                  Ahq eSports Club
# winner                                                       EDward Gaming
# blue_bans                                       ['Zed', 'Maokai', 'Sivir']
# red_bans                                 ['Azir', 'Cassiopeia', 'Hecarim']
# blue_picks                   [Irelia, Gragas, Twisted Fate, Urgot, Thresh]
# red_picks                            [Gnar, Rek'Sai, Fizz, Kalista, Annie]
# blue_roster                          [Koro1, Clearlove, PawN, Deft, Meiko]
# red_roster               [Ziv (Chen Yi), Mountain (Xue Zhao-Hong), West...
# target                                                                   1
# blue_pick_top_win                                                    100.0
# blue_pick_top_kda                                                     19.0
# blue_pick_jungle_win                                                  53.3
# blue_pick_jungle_kda                                                  3.63
# blue_pick_mid_win                                                     75.0
# blue_pick_mid_kda                                                      5.1
# blue_pick_adc_win                                                     66.7
# blue_pick_adc_kda                                                     2.84
# blue_pick_support_win                                                 60.0
# blue_pick_support_kda                                                 3.52
# blue_pick_top                                                       Irelia
# blue_pick_jungle                                                    Gragas
# blue_pick_mid                                                 Twisted Fate
# blue_pick_adc                                                        Urgot
# blue_pick_support                                                   Thresh
# red_pick_top_win                                                      38.9
# red_pick_top_kda                                                      2.64
# red_pick_jungle_win                                                   60.0
# red_pick_jungle_kda                                                   4.09
# red_pick_mid_win                                                      50.0
# red_pick_mid_kda                                                       4.5
# red_pick_adc_win                                                      60.0
# red_pick_adc_kda                                                      3.45
# red_pick_support_win                                                  62.5
# red_pick_support_kda                                                  4.55
# red_pick_top                                                          Gnar
# red_pick_jungle                                                    Rek'Sai
# red_pick_mid                                                          Fizz
# red_pick_adc                                                       Kalista
# red_pick_support                                                     Annie
# mg_championship_id                            2015_Mid-Season_Invitational
# blue_roster_top_win                                                   None
# blue_roster_top_kda                                                   None
# blue_roster_jungle_win                                                None
# blue_roster_jungle_kda                                                None
# blue_roster_mid_win                                                   None
# blue_roster_mid_kda                                                   None
# blue_roster_adc_win                                                   None
# blue_roster_adc_kda                                                   None
# blue_roster_support_win                                               None
# blue_roster_support_kda                                               None
# blue_roster_top                                                      koro1
# blue_roster_jungle                                               clearlove
# blue_roster_mid                                                       pawn
# blue_roster_adc                                                       deft
# blue_roster_support                                                  meiko
# red_roster_top_win                                                    None
# red_roster_top_kda                                                    None
# red_roster_jungle_win                                                 None
# red_roster_jungle_kda                                                 None
# red_roster_mid_win                                                    None
# red_roster_mid_kda                                                    None
# red_roster_adc_win                                                    None
# red_roster_adc_kda                                                    None
# red_roster_support_win                                                None
# red_roster_support_kda                                                None
# red_roster_top                                                         ziv
# red_roster_jungle                                                 mountain
# red_roster_mid                                                    westdoor
# red_roster_adc                                                          an
# red_roster_support                                                   albis
#
#                                                                          4
# championship_id                 2015_Mid-Season_Invitational/Match_History
# date                                                            2015-05-11
# patch                                                                  5.7
# blue_side                                                 Ahq eSports Club
# red_side                                                     EDward Gaming
# winner                                                       EDward Gaming
# blue_bans                                ['Azir', 'Cassiopeia', 'Hecarim']
# red_bans                                   ['Kalista', 'Urgot', "Rek'Sai"]
# blue_picks                          [Gnar, Gragas, Fizz, Lucian, Nautilus]
# red_picks                       [Maokai, Sejuani, Kassadin, Sivir, Thresh]
# blue_roster              [Ziv (Chen Yi), Mountain (Xue Zhao-Hong), West...
# red_roster                           [Koro1, Clearlove, PawN, Deft, Meiko]
# target                                                                   0
# blue_pick_top_win                                                     38.9
# blue_pick_top_kda                                                     2.64
# blue_pick_jungle_win                                                  53.3
# blue_pick_jungle_kda                                                  3.63
# blue_pick_mid_win                                                     50.0
# blue_pick_mid_kda                                                      4.5
# blue_pick_adc_win                                                     37.5
# blue_pick_adc_kda                                                     2.03
# blue_pick_support_win                                                 33.3
# blue_pick_support_kda                                                 2.85
# blue_pick_top                                                         Gnar
# blue_pick_jungle                                                    Gragas
# blue_pick_mid                                                         Fizz
# blue_pick_adc                                                       Lucian
# blue_pick_support                                                 Nautilus
# red_pick_top_win                                                      76.9
# red_pick_top_kda                                                      5.57
# red_pick_jungle_win                                                   23.1
# red_pick_jungle_kda                                                   2.43
# red_pick_mid_win                                                     100.0
# red_pick_mid_kda                                                     14.33
# red_pick_adc_win                                                      23.5
# red_pick_adc_kda                                                      3.31
# red_pick_support_win                                                  60.0
# red_pick_support_kda                                                  3.52
# red_pick_top                                                        Maokai
# red_pick_jungle                                                    Sejuani
# red_pick_mid                                                      Kassadin
# red_pick_adc                                                         Sivir
# red_pick_support                                                    Thresh
# mg_championship_id                            2015_Mid-Season_Invitational
# blue_roster_top_win                                                   None
# blue_roster_top_kda                                                   None
# blue_roster_jungle_win                                                None
# blue_roster_jungle_kda                                                None
# blue_roster_mid_win                                                   None
# blue_roster_mid_kda                                                   None
# blue_roster_adc_win                                                   None
# blue_roster_adc_kda                                                   None
# blue_roster_support_win                                               None
# blue_roster_support_kda                                               None
# blue_roster_top                                                        ziv
# blue_roster_jungle                                                mountain
# blue_roster_mid                                                   westdoor
# blue_roster_adc                                                         an
# blue_roster_support                                                  albis
# red_roster_top_win                                                    None
# red_roster_top_kda                                                    None
# red_roster_jungle_win                                                 None
# red_roster_jungle_kda                                                 None
# red_roster_mid_win                                                    None
# red_roster_mid_kda                                                    None
# red_roster_adc_win                                                    None
# red_roster_adc_kda                                                    None
# red_roster_support_win                                                None
# red_roster_support_kda                                                None
# red_roster_top                                                       koro1
# red_roster_jungle                                                clearlove
# red_roster_mid                                                        pawn
# red_roster_adc                                                        deft
# red_roster_support                                                   meiko

# %%
# generate keys to merge
df_player_statistics['mg_championship_id'] = df_player_statistics['championship_id']
df_player_statistics['mg_championship_id'] = df_player_statistics['championship_id'].str.replace(
    '/Player_Statistics', '', regex=False)

df_player_statistics['player'] = df_player_statistics['player'].str.replace(r'\s*\(.*?\)\s*', '', regex=True)
df_player_statistics['player'] = df_player_statistics['player'].str.lower()

# merge winrate and kda of blue rosters
for column in ['blue_roster_top', 'blue_roster_jungle', 'blue_roster_mid', 'blue_roster_adc', 'blue_roster_support']:
    df_merge = df_transformed.merge(
        df_player_statistics[['mg_championship_id', 'wr', 'kda', 'player']],
        left_on=['mg_championship_id', column],
        right_on=['mg_championship_id', 'player'],
        how='left'
    )
    df_merge['wr'] = df_merge['wr'].str.replace('%', '', regex=False).astype(float)
    df_merge['kda'] = df_merge['kda'].astype(float)
    df_transformed[f"{column}_win"] = df_merge['wr']
    df_transformed[f"{column}_kda"] = df_merge['kda']

# merge winrate and kda of red rosters
for column in ['red_roster_top', 'red_roster_jungle', 'red_roster_mid', 'red_roster_adc', 'red_roster_support']:
    df_merge = df_transformed.merge(
        df_player_statistics[['mg_championship_id', 'wr', 'kda', 'player']],
        left_on=['mg_championship_id', column],
        right_on=['mg_championship_id', 'player'],
        how='left'
    )
    df_merge['wr'] = df_merge['wr'].str.replace('%', '', regex=False).astype(float)
    df_merge['kda'] = df_merge['kda'].astype(float)
    df_transformed[f"{column}_win"] = df_merge['wr']
    df_transformed[f"{column}_kda"] = df_merge['kda']

# %%
df_transformed.head(5).T
# Out:
#                                                                        0  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  SK Telecom T1
# red_side                                                   EDward Gaming
# winner                                                     EDward Gaming
# blue_bans                                 ['Hecarim', "Rek'Sai", 'Jinx']
# red_bans                             ['Kalista', 'Gragas', 'Cassiopeia']
# blue_picks                        [Gnar, Nunu, LeBlanc, Urgot, Nautilus]
# red_picks                     [Maokai, Evelynn, Morgana, Sivir, Alistar]
# blue_roster              [MaRin, Bengi, Faker, Bang, Wolf (Lee Jae-wan)]
# red_roster                         [Koro1, Clearlove, PawN, Deft, Meiko]
# target                                                                 0
# blue_pick_top_win                                                   38.9
# blue_pick_top_kda                                                   2.64
# blue_pick_jungle_win                                                60.0
# blue_pick_jungle_kda                                                4.36
# blue_pick_mid_win                                                   60.0
# blue_pick_mid_kda                                                   6.44
# blue_pick_adc_win                                                   66.7
# blue_pick_adc_kda                                                   2.84
# blue_pick_support_win                                               33.3
# blue_pick_support_kda                                               2.85
# blue_pick_top                                                       Gnar
# blue_pick_jungle                                                    Nunu
# blue_pick_mid                                                    LeBlanc
# blue_pick_adc                                                      Urgot
# blue_pick_support                                               Nautilus
# red_pick_top_win                                                    76.9
# red_pick_top_kda                                                    5.57
# red_pick_jungle_win                                                100.0
# red_pick_jungle_kda                                                 22.0
# red_pick_mid_win                                                    33.3
# red_pick_mid_kda                                                    2.25
# red_pick_adc_win                                                    23.5
# red_pick_adc_kda                                                    3.31
# red_pick_support_win                                                77.8
# red_pick_support_kda                                                4.62
# red_pick_top                                                      Maokai
# red_pick_jungle                                                  Evelynn
# red_pick_mid                                                     Morgana
# red_pick_adc                                                       Sivir
# red_pick_support                                                 Alistar
# mg_championship_id                          2015_Mid-Season_Invitational
# blue_roster_top_win                                                 66.7
# blue_roster_top_kda                                                 2.74
# blue_roster_jungle_win                                              66.7
# blue_roster_jungle_kda                                              3.37
# blue_roster_mid_win                                                 70.0
# blue_roster_mid_kda                                                  5.6
# blue_roster_adc_win                                                 66.7
# blue_roster_adc_kda                                                  3.4
# blue_roster_support_win                                             66.7
# blue_roster_support_kda                                             2.66
# blue_roster_top                                                    marin
# blue_roster_jungle                                                 bengi
# blue_roster_mid                                                    faker
# blue_roster_adc                                                     bang
# blue_roster_support                                                 wolf
# red_roster_top_win                                                  76.9
# red_roster_top_kda                                                  6.44
# red_roster_jungle_win                                               76.9
# red_roster_jungle_kda                                               9.95
# red_roster_mid_win                                                  76.9
# red_roster_mid_kda                                                   5.9
# red_roster_adc_win                                                  76.9
# red_roster_adc_kda                                                  5.38
# red_roster_support_win                                              76.9
# red_roster_support_kda                                              6.08
# red_roster_top                                                     koro1
# red_roster_jungle                                              clearlove
# red_roster_mid                                                      pawn
# red_roster_adc                                                      deft
# red_roster_support                                                 meiko
#
#                                                                        1  \
# championship_id               2015_Mid-Season_Invitational/Match_History
# date                                                          2015-05-12
# patch                                                                5.7
# blue_side                                                  EDward Gaming
# red_side                                                   SK Telecom T1
# winner                                                     SK Telecom T1
# blue_bans                             ['Kalista', 'Cassiopeia', 'Urgot']
# red_bans                                  ['LeBlanc', "Rek'Sai", 'Jinx']
# blue_picks                            [Maokai, Nunu, Azir, Corki, Annie]
# red_picks                      [Gnar, Gragas, Kassadin, Ezreal, Alistar]
# blue_roster                        [Koro1, Clearlove, PawN, Deft, Meiko]
# red_roster               [MaRin, Bengi, Faker, Bang, Wolf (Lee Jae-wan)]
# target                                                                 0
# blue_pick_top_win                                                   76.9
# blue_pick_top_kda                                                   5.57
# blue_pick_jungle_win                                                60.0
# blue_pick_jungle_kda                                                4.36
# blue_pick_mid_win                                                   71.4
# blue_pick_mid_kda                                                    6.0
# blue_pick_adc_win                                                   33.3
# blue_pick_adc_kda                                                   2.42
# blue_pick_support_win                                               62.5
# blue_pick_support_kda                                               4.55
# blue_pick_top                                                     Maokai
# blue_pick_jungle                                                    Nunu
# blue_pick_mid                                                       Azir
# blue_pick_adc                                                      Corki
# blue_pick_support                                                  Annie
# red_pick_top_win                                                    38.9
# red_pick_top_kda                                                    2.64
# red_pick_jungle_win                                                 53.3
# red_pick_jungle_kda                                                 3.63
# red_pick_mid_win                                                   100.0
# red_pick_mid_kda                                                   14.33
# red_pick_adc_win                                                   100.0
# red_pick_adc_kda                                                   16.33
# red_pick_support_win                                                77.8
# red_pick_support_kda                                                4.62
# red_pick_top                                                        Gnar
# red_pick_jungle                                                   Gragas
# red_pick_mid                                                    Kassadin
# red_pick_adc                                                      Ezreal
# red_pick_support                                                 Alistar
# mg_championship_id                          2015_Mid-Season_Invitational
# blue_roster_top_win                                                 76.9
# blue_roster_top_kda                                                 6.44
# blue_roster_jungle_win                                              76.9
# blue_roster_jungle_kda                                              9.95
# blue_roster_mid_win                                                 76.9
# blue_roster_mid_kda                                                  5.9
# blue_roster_adc_win                                                 76.9
# blue_roster_adc_kda                                                 5.38
# blue_roster_support_win                                             76.9
# blue_roster_support_kda                                             6.08
# blue_roster_top                                                    koro1
# blue_roster_jungle                                             clearlove
# blue_roster_mid                                                     pawn
# blue_roster_adc                                                     deft
# blue_roster_support                                                meiko
# red_roster_top_win                                                  66.7
# red_roster_top_kda                                                  2.74
# red_roster_jungle_win                                               66.7
# red_roster_jungle_kda                                               3.37
# red_roster_mid_win                                                  70.0
# red_roster_mid_kda                                                   5.6
# red_roster_adc_win                                                  66.7
# red_roster_adc_kda                                                   3.4
# red_roster_support_win                                              66.7
# red_roster_support_kda                                              2.66
# red_roster_top                                                     marin
# red_roster_jungle                                                  bengi
# red_roster_mid                                                     faker
# red_roster_adc                                                      bang
# red_roster_support                                                  wolf
#
#                                                                          2  \
# championship_id                 2015_Mid-Season_Invitational/Match_History
# date                                                            2015-05-12
# patch                                                                  5.7
# blue_side                                                    SK Telecom T1
# red_side                                                     EDward Gaming
# winner                                                       EDward Gaming
# blue_bans                                 ['LeBlanc', 'Hecarim', 'Gragas']
# red_bans                                ['Kalista', 'Cassiopeia', 'Urgot']
# blue_picks                          [Rumble, Rek'Sai, Lulu, Sivir, Thresh]
# red_picks                                [Maokai, Nunu, Azir, Jinx, Annie]
# blue_roster              [MaRin, Bengi, Easyhoon, Bang, Wolf (Lee Jae-w...
# red_roster                           [Koro1, Clearlove, PawN, Deft, Meiko]
# target                                                                   0
# blue_pick_top_win                                                     45.5
# blue_pick_top_kda                                                     1.75
# blue_pick_jungle_win                                                  60.0
# blue_pick_jungle_kda                                                  4.09
# blue_pick_mid_win                                                     16.7
# blue_pick_mid_kda                                                     0.91
# blue_pick_adc_win                                                     23.5
# blue_pick_adc_kda                                                     3.31
# blue_pick_support_win                                                 60.0
# blue_pick_support_kda                                                 3.52
# blue_pick_top                                                       Rumble
# blue_pick_jungle                                                   Rek'Sai
# blue_pick_mid                                                         Lulu
# blue_pick_adc                                                        Sivir
# blue_pick_support                                                   Thresh
# red_pick_top_win                                                      76.9
# red_pick_top_kda                                                      5.57
# red_pick_jungle_win                                                   60.0
# red_pick_jungle_kda                                                   4.36
# red_pick_mid_win                                                      71.4
# red_pick_mid_kda                                                       6.0
# red_pick_adc_win                                                     100.0
# red_pick_adc_kda                                                       8.0
# red_pick_support_win                                                  62.5
# red_pick_support_kda                                                  4.55
# red_pick_top                                                        Maokai
# red_pick_jungle                                                       Nunu
# red_pick_mid                                                          Azir
# red_pick_adc                                                          Jinx
# red_pick_support                                                     Annie
# mg_championship_id                            2015_Mid-Season_Invitational
# blue_roster_top_win                                                   66.7
# blue_roster_top_kda                                                   2.74
# blue_roster_jungle_win                                                66.7
# blue_roster_jungle_kda                                                3.37
# blue_roster_mid_win                                                   60.0
# blue_roster_mid_kda                                                   4.55
# blue_roster_adc_win                                                   66.7
# blue_roster_adc_kda                                                    3.4
# blue_roster_support_win                                               66.7
# blue_roster_support_kda                                               2.66
# blue_roster_top                                                      marin
# blue_roster_jungle                                                   bengi
# blue_roster_mid                                                   easyhoon
# blue_roster_adc                                                       bang
# blue_roster_support                                                   wolf
# red_roster_top_win                                                    76.9
# red_roster_top_kda                                                    6.44
# red_roster_jungle_win                                                 76.9
# red_roster_jungle_kda                                                 9.95
# red_roster_mid_win                                                    76.9
# red_roster_mid_kda                                                     5.9
# red_roster_adc_win                                                    76.9
# red_roster_adc_kda                                                    5.38
# red_roster_support_win                                                76.9
# red_roster_support_kda                                                6.08
# red_roster_top                                                       koro1
# red_roster_jungle                                                clearlove
# red_roster_mid                                                        pawn
# red_roster_adc                                                        deft
# red_roster_support                                                   meiko
#
#                                                                          3  \
# championship_id                 2015_Mid-Season_Invitational/Match_History
# date                                                            2015-05-11
# patch                                                                  5.7
# blue_side                                                    EDward Gaming
# red_side                                                  Ahq eSports Club
# winner                                                       EDward Gaming
# blue_bans                                       ['Zed', 'Maokai', 'Sivir']
# red_bans                                 ['Azir', 'Cassiopeia', 'Hecarim']
# blue_picks                   [Irelia, Gragas, Twisted Fate, Urgot, Thresh]
# red_picks                            [Gnar, Rek'Sai, Fizz, Kalista, Annie]
# blue_roster                          [Koro1, Clearlove, PawN, Deft, Meiko]
# red_roster               [Ziv (Chen Yi), Mountain (Xue Zhao-Hong), West...
# target                                                                   1
# blue_pick_top_win                                                    100.0
# blue_pick_top_kda                                                     19.0
# blue_pick_jungle_win                                                  53.3
# blue_pick_jungle_kda                                                  3.63
# blue_pick_mid_win                                                     75.0
# blue_pick_mid_kda                                                      5.1
# blue_pick_adc_win                                                     66.7
# blue_pick_adc_kda                                                     2.84
# blue_pick_support_win                                                 60.0
# blue_pick_support_kda                                                 3.52
# blue_pick_top                                                       Irelia
# blue_pick_jungle                                                    Gragas
# blue_pick_mid                                                 Twisted Fate
# blue_pick_adc                                                        Urgot
# blue_pick_support                                                   Thresh
# red_pick_top_win                                                      38.9
# red_pick_top_kda                                                      2.64
# red_pick_jungle_win                                                   60.0
# red_pick_jungle_kda                                                   4.09
# red_pick_mid_win                                                      50.0
# red_pick_mid_kda                                                       4.5
# red_pick_adc_win                                                      60.0
# red_pick_adc_kda                                                      3.45
# red_pick_support_win                                                  62.5
# red_pick_support_kda                                                  4.55
# red_pick_top                                                          Gnar
# red_pick_jungle                                                    Rek'Sai
# red_pick_mid                                                          Fizz
# red_pick_adc                                                       Kalista
# red_pick_support                                                     Annie
# mg_championship_id                            2015_Mid-Season_Invitational
# blue_roster_top_win                                                   76.9
# blue_roster_top_kda                                                   6.44
# blue_roster_jungle_win                                                76.9
# blue_roster_jungle_kda                                                9.95
# blue_roster_mid_win                                                   76.9
# blue_roster_mid_kda                                                    5.9
# blue_roster_adc_win                                                   76.9
# blue_roster_adc_kda                                                   5.38
# blue_roster_support_win                                               76.9
# blue_roster_support_kda                                               6.08
# blue_roster_top                                                      koro1
# blue_roster_jungle                                               clearlove
# blue_roster_mid                                                       pawn
# blue_roster_adc                                                       deft
# blue_roster_support                                                  meiko
# red_roster_top_win                                                    37.5
# red_roster_top_kda                                                    3.23
# red_roster_jungle_win                                                 37.5
# red_roster_jungle_kda                                                 3.03
# red_roster_mid_win                                                    37.5
# red_roster_mid_kda                                                    3.73
# red_roster_adc_win                                                    37.5
# red_roster_adc_kda                                                    3.77
# red_roster_support_win                                                37.5
# red_roster_support_kda                                                3.54
# red_roster_top                                                         ziv
# red_roster_jungle                                                 mountain
# red_roster_mid                                                    westdoor
# red_roster_adc                                                          an
# red_roster_support                                                   albis
#
#                                                                          4
# championship_id                 2015_Mid-Season_Invitational/Match_History
# date                                                            2015-05-11
# patch                                                                  5.7
# blue_side                                                 Ahq eSports Club
# red_side                                                     EDward Gaming
# winner                                                       EDward Gaming
# blue_bans                                ['Azir', 'Cassiopeia', 'Hecarim']
# red_bans                                   ['Kalista', 'Urgot', "Rek'Sai"]
# blue_picks                          [Gnar, Gragas, Fizz, Lucian, Nautilus]
# red_picks                       [Maokai, Sejuani, Kassadin, Sivir, Thresh]
# blue_roster              [Ziv (Chen Yi), Mountain (Xue Zhao-Hong), West...
# red_roster                           [Koro1, Clearlove, PawN, Deft, Meiko]
# target                                                                   0
# blue_pick_top_win                                                     38.9
# blue_pick_top_kda                                                     2.64
# blue_pick_jungle_win                                                  53.3
# blue_pick_jungle_kda                                                  3.63
# blue_pick_mid_win                                                     50.0
# blue_pick_mid_kda                                                      4.5
# blue_pick_adc_win                                                     37.5
# blue_pick_adc_kda                                                     2.03
# blue_pick_support_win                                                 33.3
# blue_pick_support_kda                                                 2.85
# blue_pick_top                                                         Gnar
# blue_pick_jungle                                                    Gragas
# blue_pick_mid                                                         Fizz
# blue_pick_adc                                                       Lucian
# blue_pick_support                                                 Nautilus
# red_pick_top_win                                                      76.9
# red_pick_top_kda                                                      5.57
# red_pick_jungle_win                                                   23.1
# red_pick_jungle_kda                                                   2.43
# red_pick_mid_win                                                     100.0
# red_pick_mid_kda                                                     14.33
# red_pick_adc_win                                                      23.5
# red_pick_adc_kda                                                      3.31
# red_pick_support_win                                                  60.0
# red_pick_support_kda                                                  3.52
# red_pick_top                                                        Maokai
# red_pick_jungle                                                    Sejuani
# red_pick_mid                                                      Kassadin
# red_pick_adc                                                         Sivir
# red_pick_support                                                    Thresh
# mg_championship_id                            2015_Mid-Season_Invitational
# blue_roster_top_win                                                   37.5
# blue_roster_top_kda                                                   3.23
# blue_roster_jungle_win                                                37.5
# blue_roster_jungle_kda                                                3.03
# blue_roster_mid_win                                                   37.5
# blue_roster_mid_kda                                                   3.73
# blue_roster_adc_win                                                   37.5
# blue_roster_adc_kda                                                   3.77
# blue_roster_support_win                                               37.5
# blue_roster_support_kda                                               3.54
# blue_roster_top                                                        ziv
# blue_roster_jungle                                                mountain
# blue_roster_mid                                                   westdoor
# blue_roster_adc                                                         an
# blue_roster_support                                                  albis
# red_roster_top_win                                                    76.9
# red_roster_top_kda                                                    6.44
# red_roster_jungle_win                                                 76.9
# red_roster_jungle_kda                                                 9.95
# red_roster_mid_win                                                    76.9
# red_roster_mid_kda                                                     5.9
# red_roster_adc_win                                                    76.9
# red_roster_adc_kda                                                    5.38
# red_roster_support_win                                                76.9
# red_roster_support_kda                                                6.08
# red_roster_top                                                       koro1
# red_roster_jungle                                                clearlove
# red_roster_mid                                                        pawn
# red_roster_adc                                                        deft
# red_roster_support                                                   meiko

# %% [markdown]
# ## Dummies picks

# %%
blue_picks = pd.get_dummies(df_transformed['blue_picks'].explode(), prefix='blue_picks')
df_transformed = pd.concat([df_transformed, blue_picks.groupby(level=0).sum()], axis=1).drop('blue_picks', axis=1)

# %%
red_picks = pd.get_dummies(df_transformed['red_picks'].explode(), prefix='red_picks')
df_transformed = pd.concat([df_transformed, red_picks.groupby(level=0).sum()], axis=1).drop('red_picks', axis=1)

# %% [markdown]
# ## Drop features that will not be used by the model

# %%
df_transformed.columns
# Out:
# Index(['championship_id', 'date', 'patch', 'blue_side', 'red_side', 'winner',
#        'blue_bans', 'red_bans', 'blue_roster', 'red_roster',
#        ...
#        'red_picks_Yone', 'red_picks_Yorick', 'red_picks_Yuumi',
#        'red_picks_Zac', 'red_picks_Zed', 'red_picks_Zeri', 'red_picks_Ziggs',
#        'red_picks_Zilean', 'red_picks_Zoe', 'red_picks_Zyra'],
#       dtype='object', length=405)

# %%
df_transformed.drop(columns=[
    'championship_id',
    'date',
    'patch',
    'blue_side',
    'red_side',
    'winner',
    'blue_bans',
    'red_bans',
    # 'blue_picks',
    # 'red_picks',
    'blue_roster',
    'red_roster',
    'championship_id',
    'mg_championship_id',
    'blue_pick_top',
    'blue_pick_jungle',
    'blue_pick_mid',
    'blue_pick_adc',
    'blue_pick_support',
    'red_pick_top',
    'red_pick_jungle',
    'red_pick_mid',
    'red_pick_adc',
    'red_pick_support',
    'blue_roster_top',
    'blue_roster_jungle',
    'blue_roster_mid',
    'blue_roster_adc',
    'blue_roster_support',
    'red_roster_top',
    'red_roster_jungle',
    'red_roster_mid',
    'red_roster_adc',
    'red_roster_support'
], inplace=True)

# %% [markdown]
# ## Analysis transformed dataset.

# %%
df_transformed.shape
# Out:
# (16225, 374)

# %%
df_filter = df_transformed[df_transformed['blue_roster_top_win'].isnull()]
df_filter.head(2).T
# Out:
#                          1951  1953
# target                      1     1
# blue_pick_top_win        52.2  42.1
# blue_pick_top_kda        2.24  1.98
# blue_pick_jungle_win     50.0  51.2
# blue_pick_jungle_kda     2.61  3.61
# blue_pick_mid_win        56.0  43.8
# blue_pick_mid_kda        3.42  4.38
# blue_pick_adc_win        56.8  57.1
# blue_pick_adc_kda        4.16  4.58
# blue_pick_support_win    58.6  44.1
# blue_pick_support_kda    2.71   2.5
# red_pick_top_win         46.2  52.2
# red_pick_top_kda         3.14  2.24
# red_pick_jungle_win      61.3  45.9
# red_pick_jungle_kda      4.12  3.95
# red_pick_mid_win         51.1  56.0
# red_pick_mid_kda         4.03  3.42
# red_pick_adc_win         57.1  56.8
# red_pick_adc_kda         4.58  4.16
# red_pick_support_win     55.8  50.0
# red_pick_support_kda     3.74  2.61
# blue_roster_top_win       NaN   NaN
# blue_roster_top_kda       NaN   NaN
# blue_roster_jungle_win   48.6  48.6
# blue_roster_jungle_kda   2.84  2.84
# blue_roster_mid_win      48.6  48.6
# blue_roster_mid_kda       2.7   2.7
# blue_roster_adc_win      48.6  48.6
# blue_roster_adc_kda      3.94  3.94
# blue_roster_support_win  57.1  57.1
# blue_roster_support_kda  2.63  2.63
# red_roster_top_win       36.8  36.8
# red_roster_top_kda       2.04  2.04
# red_roster_jungle_win    36.8  36.8
# red_roster_jungle_kda    4.72  4.72
# red_roster_mid_win       36.7  36.7
# red_roster_mid_kda       2.76  2.76
# red_roster_adc_win       37.1  37.1
# red_roster_adc_kda       2.53  2.53
# red_roster_support_win   36.8  36.8
# red_roster_support_kda   2.54  2.54
# blue_picks_Aatrox           0     0
# blue_picks_Ahri             0     0
# blue_picks_Akali            0     0
# blue_picks_Akshan           0     0
# blue_picks_Alistar          0     0
# blue_picks_Amumu            0     0
# blue_picks_Anivia           0     0
# blue_picks_Annie            0     0
# blue_picks_Aphelios         0     0
# blue_picks_Ashe             0     0
# blue_picks_Aurelion Sol     0     0
# blue_picks_Aurora           0     0
# blue_picks_Azir             0     0
# blue_picks_Bard             0     0
# blue_picks_Bel'Veth         0     0
# blue_picks_Blitzcrank       0     0
# blue_picks_Brand            0     0
# blue_picks_Braum            0     0
# blue_picks_Caitlyn          0     0
# blue_picks_Camille          0     0
# blue_picks_Cassiopeia       0     0
# blue_picks_Cho'Gath         0     0
# blue_picks_Corki            0     0
# blue_picks_Darius           0     0
# blue_picks_Diana            0     0
# blue_picks_Dr. Mundo        0     0
# blue_picks_Draven           0     0
# blue_picks_Ekko             0     0
# blue_picks_Elise            0     0
# blue_picks_Evelynn          0     0
# blue_picks_Ezreal           0     0
# blue_picks_Fiddlesticks     0     0
# blue_picks_Fiora            0     0
# blue_picks_Fizz             0     0
# blue_picks_Galio            0     0
# blue_picks_Gangplank        0     0
# blue_picks_Garen            0     0
# blue_picks_Gnar             1     0
# blue_picks_Gragas           1     0
# blue_picks_Graves           0     0
# blue_picks_Gwen             0     0
# blue_picks_Hecarim          0     1
# blue_picks_Heimerdinger     0     0
# blue_picks_Hwei             0     0
# blue_picks_Illaoi           0     0
# blue_picks_Irelia           0     0
# blue_picks_Ivern            0     0
# blue_picks_Janna            0     0
# blue_picks_Jarvan IV        0     0
# blue_picks_Jax              0     0
# blue_picks_Jayce            0     1
# blue_picks_Jhin             0     0
# blue_picks_Jinx             0     0
# blue_picks_K'Sante          0     0
# blue_picks_Kai'Sa           0     1
# blue_picks_Kalista          0     0
# blue_picks_Karma            0     0
# blue_picks_Karthus          0     0
# blue_picks_Kassadin         0     0
# blue_picks_Katarina         0     0
# blue_picks_Kayle            0     0
# blue_picks_Kayn             0     0
# blue_picks_Kennen           0     0
# blue_picks_Kha'Zix          0     0
# blue_picks_Kindred          0     0
# blue_picks_Kled             0     0
# blue_picks_Kog'Maw          0     0
# blue_picks_LeBlanc          0     0
# blue_picks_Lee Sin          0     0
# blue_picks_Leona            0     1
# blue_picks_Lillia           0     0
# blue_picks_Lissandra        0     0
# blue_picks_Lucian           0     0
# blue_picks_Lulu             0     0
# blue_picks_Lux              0     0
# blue_picks_Malphite         0     0
# blue_picks_Malzahar         0     0
# blue_picks_Maokai           0     0
# blue_picks_Master Yi        0     0
# blue_picks_Milio            0     0
# blue_picks_Miss Fortune     0     0
# blue_picks_Mordekaiser      0     0
# blue_picks_Morgana          0     0
# blue_picks_Naafiri          0     0
# blue_picks_Nami             0     0
# blue_picks_Nasus            0     0
# blue_picks_Nautilus         0     0
# blue_picks_Neeko            0     0
# blue_picks_Nidalee          0     0
# blue_picks_Nilah            0     0
# blue_picks_Nocturne         0     0
# blue_picks_Nunu             0     0
# blue_picks_Olaf             0     0
# blue_picks_Orianna          0     0
# blue_picks_Ornn             0     0
# blue_picks_Pantheon         0     0
# blue_picks_Poppy            0     0
# blue_picks_Pyke             0     0
# blue_picks_Qiyana           0     0
# blue_picks_Quinn            0     0
# blue_picks_Rakan            0     0
# blue_picks_Rammus           0     0
# blue_picks_Rek'Sai          0     0
# blue_picks_Rell             0     0
# blue_picks_Renata Glasc     0     0
# blue_picks_Renekton         0     0
# blue_picks_Rengar           0     0
# blue_picks_Riven            0     0
# blue_picks_Rumble           0     0
# blue_picks_Ryze             0     0
# blue_picks_Samira           0     0
# blue_picks_Sejuani          0     0
# blue_picks_Senna            0     0
# blue_picks_Seraphine        0     0
# blue_picks_Sett             1     0
# blue_picks_Shaco            0     0
# blue_picks_Shen             0     0
# blue_picks_Shyvana          0     0
# blue_picks_Singed           0     0
# blue_picks_Sion             0     0
# blue_picks_Sivir            0     0
# blue_picks_Skarner          0     0
# blue_picks_Smolder          0     0
# blue_picks_Sona             0     0
# blue_picks_Soraka           0     0
# blue_picks_Swain            0     0
# blue_picks_Sylas            0     0
# blue_picks_Syndra           1     0
# blue_picks_Tahm Kench       0     0
# blue_picks_Taliyah          0     0
# blue_picks_Talon            0     0
# blue_picks_Taric            0     0
# blue_picks_Teemo            0     0
# blue_picks_Thresh           0     0
# blue_picks_Tristana         1     0
# blue_picks_Trundle          0     0
# blue_picks_Tryndamere       0     0
# blue_picks_Twisted Fate     0     1
# blue_picks_Twitch           0     0
# blue_picks_Udyr             0     0
# blue_picks_Urgot            0     0
# blue_picks_Varus            0     0
# blue_picks_Vayne            0     0
# blue_picks_Veigar           0     0
# blue_picks_Vel'Koz          0     0
# blue_picks_Vex              0     0
# blue_picks_Vi               0     0
# blue_picks_Viego            0     0
# blue_picks_Viktor           0     0
# blue_picks_Vladimir         0     0
# blue_picks_Volibear         0     0
# blue_picks_Warwick          0     0
# blue_picks_Wukong           0     0
# blue_picks_Xayah            0     0
# blue_picks_Xerath           0     0
# blue_picks_Xin Zhao         0     0
# blue_picks_Yasuo            0     0
# blue_picks_Yone             0     0
# blue_picks_Yorick           0     0
# blue_picks_Yuumi            0     0
# blue_picks_Zac              0     0
# blue_picks_Zed              0     0
# blue_picks_Zeri             0     0
# blue_picks_Ziggs            0     0
# blue_picks_Zilean           0     0
# blue_picks_Zoe              0     0
# blue_picks_Zyra             0     0
# red_picks_Aatrox            0     0
# red_picks_Ahri              0     0
# red_picks_Akali             0     0
# red_picks_Akshan            0     0
# red_picks_Alistar           0     0
# red_picks_Amumu             0     0
# red_picks_Anivia            0     0
# red_picks_Annie             0     0
# red_picks_Aphelios          0     0
# red_picks_Ashe              0     0
# red_picks_Aurelion Sol      0     0
# red_picks_Aurora            0     0
# red_picks_Azir              0     0
# red_picks_Bard              0     0
# red_picks_Bel'Veth          0     0
# red_picks_Blitzcrank        0     0
# red_picks_Brand             0     0
# red_picks_Braum             0     0
# red_picks_Caitlyn           0     0
# red_picks_Camille           0     0
# red_picks_Cassiopeia        0     0
# red_picks_Cho'Gath          0     0
# red_picks_Corki             0     0
# red_picks_Darius            0     0
# red_picks_Diana             0     0
# red_picks_Dr. Mundo         0     0
# red_picks_Draven            0     0
# red_picks_Ekko              0     0
# red_picks_Elise             0     0
# red_picks_Evelynn           0     0
# red_picks_Ezreal            0     0
# red_picks_Fiddlesticks      0     0
# red_picks_Fiora             0     0
# red_picks_Fizz              0     0
# red_picks_Galio             1     0
# red_picks_Gangplank         0     0
# red_picks_Garen             0     0
# red_picks_Gnar              0     1
# red_picks_Gragas            0     1
# red_picks_Graves            0     0
# red_picks_Gwen              0     0
# red_picks_Hecarim           0     0
# red_picks_Heimerdinger      0     0
# red_picks_Hwei              0     0
# red_picks_Illaoi            0     0
# red_picks_Irelia            0     0
# red_picks_Ivern             0     0
# red_picks_Janna             0     0
# red_picks_Jarvan IV         0     0
# red_picks_Jax               0     0
# red_picks_Jayce             0     0
# red_picks_Jhin              0     0
# red_picks_Jinx              0     0
# red_picks_K'Sante           0     0
# red_picks_Kai'Sa            1     0
# red_picks_Kalista           0     0
# red_picks_Karma             0     0
# red_picks_Karthus           0     0
# red_picks_Kassadin          0     0
# red_picks_Katarina          0     0
# red_picks_Kayle             0     0
# red_picks_Kayn              0     0
# red_picks_Kennen            0     0
# red_picks_Kha'Zix           0     0
# red_picks_Kindred           0     0
# red_picks_Kled              0     0
# red_picks_Kog'Maw           0     0
# red_picks_LeBlanc           0     0
# red_picks_Lee Sin           0     0
# red_picks_Leona             0     0
# red_picks_Lillia            0     0
# red_picks_Lissandra         0     0
# red_picks_Lucian            0     0
# red_picks_Lulu              0     0
# red_picks_Lux               0     0
# red_picks_Malphite          0     0
# red_picks_Malzahar          0     0
# red_picks_Maokai            0     0
# red_picks_Master Yi         0     0
# red_picks_Milio             0     0
# red_picks_Miss Fortune      0     0
# red_picks_Mordekaiser       0     0
# red_picks_Morgana           0     0
# red_picks_Nami              0     0
# red_picks_Nasus             0     0
# red_picks_Nautilus          0     0
# red_picks_Neeko             0     0
# red_picks_Nidalee           0     0
# red_picks_Nilah             0     0
# red_picks_Nocturne          0     0
# red_picks_Nunu              0     0
# red_picks_Olaf              1     0
# red_picks_Orianna           1     0
# red_picks_Ornn              1     0
# red_picks_Pantheon          0     0
# red_picks_Poppy             0     0
# red_picks_Pyke              0     0
# red_picks_Qiyana            0     0
# red_picks_Quinn             0     0
# red_picks_Rakan             0     0
# red_picks_Rammus            0     0
# red_picks_Rek'Sai           0     0
# red_picks_Rell              0     0
# red_picks_Renata Glasc      0     0
# red_picks_Renekton          0     0
# red_picks_Rengar            0     0
# red_picks_Riven             0     0
# red_picks_Rumble            0     0
# red_picks_Ryze              0     0
# red_picks_Samira            0     0
# red_picks_Sejuani           0     0
# red_picks_Senna             0     0
# red_picks_Seraphine         0     0
# red_picks_Sett              0     0
# red_picks_Shaco             0     0
# red_picks_Shen              0     0
# red_picks_Shyvana           0     0
# red_picks_Singed            0     0
# red_picks_Sion              0     0
# red_picks_Sivir             0     0
# red_picks_Skarner           0     0
# red_picks_Smolder           0     0
# red_picks_Sona              0     0
# red_picks_Soraka            0     0
# red_picks_Swain             0     0
# red_picks_Sylas             0     0
# red_picks_Syndra            0     1
# red_picks_Tahm Kench        0     0
# red_picks_Taliyah           0     0
# red_picks_Talon             0     0
# red_picks_Taric             0     0
# red_picks_Teemo             0     0
# red_picks_Thresh            0     0
# red_picks_Tristana          0     1
# red_picks_Trundle           0     0
# red_picks_Tryndamere        0     0
# red_picks_Twisted Fate      0     0
# red_picks_Twitch            0     0
# red_picks_Udyr              0     1
# red_picks_Urgot             0     0
# red_picks_Varus             0     0
# red_picks_Vayne             0     0
# red_picks_Veigar            0     0
# red_picks_Vel'Koz           0     0
# red_picks_Vex               0     0
# red_picks_Vi                0     0
# red_picks_Viego             0     0
# red_picks_Viktor            0     0
# red_picks_Vladimir          0     0
# red_picks_Volibear          0     0
# red_picks_Warwick           0     0
# red_picks_Wukong            0     0
# red_picks_Xayah             0     0
# red_picks_Xerath            0     0
# red_picks_Xin Zhao          0     0
# red_picks_Yasuo             0     0
# red_picks_Yone              0     0
# red_picks_Yorick            0     0
# red_picks_Yuumi             0     0
# red_picks_Zac               0     0
# red_picks_Zed               0     0
# red_picks_Zeri              0     0
# red_picks_Ziggs             0     0
# red_picks_Zilean            0     0
# red_picks_Zoe               0     0
# red_picks_Zyra              0     0

# %%
skim(df_transformed)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 16225  │ │ int64       │ 334   │                                                          │
# │ │ Number of columns │ 374    │ │ float64     │ 40    │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column_name           ┃ NA  ┃ NA %  ┃ mean       ┃ sd       ┃ p0   ┃ p25   ┃ p50   ┃ p75  ┃ p100  ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━━┩  │
# │ │ target                │   0 │     0 │     0.5344 │   0.4988 │    0 │     0 │     1 │    1 │     1 │ ▇    ▇ │  │
# │ │ blue_pick_top_win     │   0 │     0 │      50.66 │     15.7 │    0 │  43.8 │    50 │ 57.7 │   100 │  ▁▅▇▂  │  │
# │ │ blue_pick_top_kda     │   0 │     0 │      3.046 │    1.443 │    0 │  2.37 │  2.83 │ 3.46 │    44 │   ▇    │  │
# │ │ blue_pick_jungle_win  │   0 │     0 │      50.64 │    15.19 │    0 │  44.4 │    50 │ 58.3 │   100 │  ▁▆▇▂  │  │
# │ │ blue_pick_jungle_kda  │   0 │     0 │      3.606 │    1.486 │    0 │   2.9 │  3.45 │ 4.07 │    32 │   ▇    │  │
# │ │ blue_pick_mid_win     │   0 │     0 │      50.73 │    16.65 │    0 │  42.9 │  50.6 │ 58.9 │   100 │ ▁▁▅▇▂  │  │
# │ │ blue_pick_mid_kda     │   0 │     0 │      3.991 │    1.896 │    0 │     3 │   3.7 │ 4.59 │    54 │   ▇    │  │
# │ │ blue_pick_adc_win     │   0 │     0 │      50.85 │    15.23 │    0 │  44.4 │  50.8 │ 57.9 │   100 │  ▁▅▇▁  │  │
# │ │ blue_pick_adc_kda     │   0 │     0 │      4.344 │    1.944 │    0 │  3.46 │  4.05 │ 4.76 │    36 │   ▇▁   │  │
# │ │ blue_pick_support_win │   0 │     0 │      50.57 │    15.08 │    0 │  43.8 │    50 │ 57.1 │   100 │  ▁▆▇▁  │  │
# │ │ blue_pick_support_kda │   0 │     0 │      3.619 │     2.16 │    0 │  2.56 │  3.22 │    4 │    48 │   ▇    │  │
# │ │ red_pick_top_win      │   0 │     0 │       49.6 │    17.23 │    0 │  42.9 │    50 │ 57.1 │   100 │ ▁▂▆▇▂▁ │  │
# │ │ red_pick_top_kda      │   0 │     0 │      2.996 │    1.445 │    0 │  2.32 │  2.79 │ 3.42 │    44 │   ▇    │  │
# │ │ red_pick_jungle_win   │   0 │     0 │       49.6 │    14.94 │    0 │  43.8 │    50 │ 57.1 │   100 │ ▁▁▆▇▁  │  │
# │ │ red_pick_jungle_kda   │   0 │     0 │      3.531 │    1.343 │    0 │  2.87 │  3.41 │    4 │    32 │   ▇    │  │
# │ │ red_pick_mid_win      │   0 │     0 │      49.35 │    17.62 │    0 │  41.7 │    50 │ 58.3 │   100 │ ▁▂▅▇▂▁ │  │
# │ │ red_pick_mid_kda      │   0 │     0 │      3.951 │     2.08 │    0 │  2.92 │  3.65 │  4.5 │    54 │   ▇    │  │
# │ │ red_pick_adc_win      │   0 │     0 │      49.57 │    15.17 │    0 │  43.5 │    50 │ 57.1 │   100 │ ▁▁▆▇▁  │  │
# │ │ red_pick_adc_kda      │   0 │     0 │      4.222 │    1.799 │    0 │  3.41 │     4 │ 4.68 │    36 │   ▇▁   │  │
# │ │ red_pick_support_win  │   0 │     0 │       49.8 │    15.28 │    0 │    43 │    50 │   57 │   100 │ ▁▁▆▇▁  │  │
# │ │ red_pick_support_kda  │   0 │     0 │      3.517 │    1.913 │    0 │  2.54 │  3.18 │ 3.95 │    48 │   ▇    │  │
# │ │ blue_roster_top_win   │   4 │  0.02 │      50.16 │    19.37 │    0 │  37.5 │    50 │ 63.6 │   100 │ ▁▃▅▇▅▁ │  │
# │ │ blue_roster_top_kda   │   4 │  0.02 │      2.973 │    1.208 │    0 │  2.19 │  2.81 │ 3.55 │    24 │   ▇▁   │  │
# │ │ blue_roster_jungle_wi │   5 │  0.03 │      50.16 │     19.4 │    0 │  37.5 │    50 │ 63.4 │   100 │ ▁▃▆▇▅▁ │  │
# │ │ n                     │     │       │            │          │      │       │       │      │       │        │  │
# │ │ blue_roster_jungle_kd │   5 │  0.03 │      3.698 │    1.564 │  0.2 │  2.69 │  3.44 │ 4.33 │    21 │   ▇▅   │  │
# │ │ a                     │     │       │            │          │      │       │       │      │       │        │  │
# │ │ blue_roster_mid_win   │   3 │  0.02 │      50.15 │     19.2 │    0 │  37.5 │    50 │ 63.3 │   100 │ ▁▃▆▇▅▁ │  │
# │ │ blue_roster_mid_kda   │   3 │  0.02 │      4.034 │    1.749 │    0 │  2.92 │  3.75 │ 4.78 │ 26.33 │   ▇▃   │  │
# │ │ blue_roster_adc_win   │   7 │  0.04 │      50.05 │    19.24 │    0 │  37.1 │    50 │ 63.2 │   100 │ ▁▅▆▇▅▁ │  │
# │ │ blue_roster_adc_kda   │   7 │  0.04 │       4.43 │    2.085 │  0.2 │  3.17 │   4.1 │ 5.25 │ 35.33 │   ▇▁   │  │
# │ │ blue_roster_support_w │  11 │  0.07 │      50.13 │    19.32 │    0 │  37.5 │    50 │ 63.4 │   100 │ ▁▃▆▇▅▁ │  │
# │ │ in                    │     │       │            │          │      │       │       │      │       │        │  │
# │ │ blue